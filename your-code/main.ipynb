# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
questions = SITE.fetch('questions', fromdate=1559340000, todate=1561931940)

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['php', 'woocommerce', 'roles', 'shipping'],
#    'owner': {'reputation': 23,
#     'user_id': 7119037,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d75ae365d86198821766185274298a99?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Lyse',
#     'link': 'https://stackoverflow.com/users/7119037/lyse'},
#    'is_answered': False,
#    'view_count': 19,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1562853515,
#    'creation_date': 1561148490,
#    'question_id': 56709972,
#    'link': 'https://stackoverflow.com/questions/56709972/hide-specific-shipping-methods-for-specific-customer-roles',
#    'title': 'Hide specific shipping methods for specific customer roles'},
#   {'tags': ['python', 'python-3.x', 'function', 'loops', 'if-statement'],
#    'owner': {'reputation': 7,
# ...

# %%
answers = SITE.fetch('answers', fromdate=1559340000, todate=1561931940)

# %%
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 396,
#     'user_id': 1018861,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://www.gravatar.com/avatar/e4df1317aa64a5f6550ff47202bbc5a0?s=128&d=identicon&r=PG',
#     'display_name': 'TomNorway',
#     'link': 'https://stackoverflow.com/users/1018861/tomnorway'},
#    'is_accepted': False,
#    'score': 4,
#    'last_activity_date': 1562853121,
#    'last_edit_date': 1562853121,
#    'creation_date': 1559487893,
#    'answer_id': 56416229,
#    'question_id': 51922480},
#   {'owner': {'reputation': 17453,
#     'user_id': 2252113,
#     'user_type': 'registered',
#     'accept_rate': 57,
#     'profile_image': 'https://i.stack.imgur.com/TTazp.png?s=128&g=1',
#     'display_name': 'Hitesh Sahu',
#     'link': 'https://stackoverflow.com/users/2252113/hitesh-sahu'},
#    'is_accepted': False,
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
questions = SITE.fetch('questions', fromdate=1562796000, todate=1562843112,
     tagged='python', sort ='votes', min=5)

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'pandas', 'dataframe'],
#    'owner': {'reputation': 70,
#     'user_id': 8561125,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/1EBVj.jpg?s=128&g=1',
#     'display_name': 'Ching',
#     'link': 'https://stackoverflow.com/users/8561125/ching'},
#    'is_answered': True,
#    'view_count': 62,
#    'accepted_answer_id': 56982159,
#    'answer_count': 1,
#    'score': 5,
#    'last_activity_date': 1562823432,
#    'creation_date': 1562822209,
#    'last_edit_date': 1562822348,
#    'question_id': 56982048,
#    'link': 'https://stackoverflow.com/questions/56982048/find-element-in-list-in-datafame',
#    'title': 'find element in list in datafame'}]}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
answer_id = SITE.fetch('answers', ids = [6784,6473])
# post = SITE.fetch('posts', ids=[3743, 327738, 339426], sort='activity', order='desc')

# %%
answer_id
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 22234,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}

# %% [markdown]
# Looking at the results we can see that there is only one ID in the response json, that is 6784. However, we can try to request the other ID to see if there is the other answer ID or no.

# %%
answer_id_6473 = SITE.fetch('answers', ids = [6473])

# %%
answer_id_6473
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': []}

# %% [markdown]
# Here, we can see that the other ID is not found.
